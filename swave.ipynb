# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import eigh

# %%
e, hbar, m = 3.795, 1973, 0.511e6
h2m = hbar**2 / (2 * m)

N, r_max = 1000, 20
dr = r_max/N
r = np.linspace(dr, r_max, N)

# %%
V = -e**2 / r 
T = np.array([np.array([-2 if i==j else 1 if abs(i-j) == 1 else 0 for j in range(N)]) for i in range(N)])
H = - h2m * T / dr**2 + np.diag(V)

# %%
val, vec = eigh(H)
n = 4

# print 1st n values
print(val[:n])

plt.figure(figsize=(8, 5))
for i in range(n):
    E = val[i]
    psi = vec[:, i] / np.sqrt(dr)
    plt.plot(r, psi**2, label = f"E = {E:.3f} eV")

plt.xlabel("r")
plt.ylabel("$|\psi(r)|^2$")
plt.legend()
plt.title("Radial Probability Density of Hydrogen Atom")
plt.grid()
plt.show()
# Out:
# [-13.60907827  -3.40318111  -1.51249746  -0.81889609]
